# %%
from graphql_executor import ShopifyGraphQLClient
import requests

class ShopifyGraphQLClient:
    def __init__(self):
        self.endpoint = f"https://{"aitken-store-2"}.myshopify.com/admin/api/2025-10/graphql.json"
        self.headers = {
            'Content-Type': 'application/json',
            'X-Shopify-Access-Token': "shpat_b0bd..."
        }
    
    def execute_query(self, query, variables=None):
        payload = {'query': query}
        if variables:
            payload['variables'] = variables
        
        response = requests.post(self.endpoint, json=payload, headers=self.headers)
        response.raise_for_status()
        return response.json()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from graphql_executor import ShopifyGraphQLClient
#       2 import requests
#       4 class ShopifyGraphQLClient:
#
# ModuleNotFoundError: No module named 'graphql_executor'

# %%
docker run -p 6333:6333 -p 6334:6334 -v "$(pwd)/qdrant_storage:/qdrant/storage:z" qdrant/qdrant
# Out:
#   Cell In[5], line 1
#     docker run -p 6333:6333 -p 6334:6334 \
#            ^
# SyntaxError: invalid syntax

# %%
client = ShopifyGraphQLClient()
query = """
query {
  shop {
    id
    name
    email
    billingAddress {
      id
      address1
    }
  }
  products(first:10) {
    nodes {
      id
      title
      description
    }
  }
}
"""
client.execute_query(query)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[2], line 22
#       1 client = ShopifyGraphQLClient()
#       2 query = """
#       3 query {
#       4   shop {
#    (...)     20 }
#      21 """
# ---> 22 client.execute_query(query)
#
# Cell In[1], line 17, in ShopifyGraphQLClient.execute_query(self, query, variables)
#      14     payload['variables'] = variables
#      16 response = requests.post(self.endpoint, json=payload, headers=self.headers)
# ---> 17 response.raise_for_status()
#      18 return response.json()
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\models.py:1026, in Response.raise_for_status(self)
#    1021     http_error_msg = (
#    1022         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1023     )
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 401 Client Error: Unauthorized for url: https://aitken-store-2.myshopify.com/admin/api/2025-10/graphql.json

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from graphql_executor import ShopifyGraphQLClient
#
# ModuleNotFoundError: No module named 'graphql_executor'
